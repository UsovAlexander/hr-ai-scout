# %%
import pickle
import pandas as pd
import numpy as np
import scipy.sparse as sp
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.feature_extraction.text import TfidfVectorizer
from modules import tokenize_and_lemmatize

import warnings
warnings.simplefilter('ignore')
# Out:
# [nltk_data] Downloading package wordnet to /Users/user/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# # Load data

# %%
vacancy_name = 'Аналитик данных/data analyst'
vacancy_area = 'Москва'
vacancy_experience = 'От 1 года до 3 лет'
vacancy_employment = 'Полная занятость'
vacancy_schedule = 'Полный день'
vacancy_description = 'Твои задачи:• Формирование баз данных для КЦ (сбор, консолидация, проверка качества и актуальности).• Работа с источниками данных (поиск, анализ конверсии, отчётность) через собственную платформу.• Аналитика и отчётность (отчёты, выводы, рекомендации).• Поддержка контента и скриптов (анализ и корректировки).Что мы ждем:Hard skills:• Понимание метрик аналитики и маркетинга (CTR, CR, CPL, ROI, UTM).• • Навыки сбора, очистки и визуализации данных.. Продвинутое владение Excel / Google Таблицами (формулы, сводные таблицы, Power Query).· Опыт работы с системами визуализации данных (например, Power BI или Google Looker Studio) будет преимуществом.· Понимание ключевых маркетинговых метрик: конверсия (CR), стоимость лида (CPL), возврат на инвестиции (ROI).· Навыки работы с большими массивами информации: сбор, очистка, структурирование.Личностные Soft Skills:· Внимательность к деталям и аккуратность.· Системный и аналитический подход к решению задач.· Ответственность и нацеленность на конкретный результат.· Инициативность.Условия:Зарплата: от 80 000 ₽ (обсуждается по итогам собеседования).(Выплаты 3 раза в месяц!)· Тестовый период: 3 дня (полностью оплачиваются).· Возможности для роста: Карьерный рост до ведущего аналитика или менеджера по маркетинговым каналам.KNAM.PRO — это про результат, рост и большие деньги.Если хочешь быть в команде, которая делает рынок лидогенерации №1 в России — жми “Откликнуться”!'

# %%
input_dict = {
    'vacancy_name': vacancy_name,
    'vacancy_area': vacancy_area,
    'vacancy_experience': vacancy_experience,
    'vacancy_employment': vacancy_employment,
    'vacancy_schedule': vacancy_schedule,
    'vacancy_description': vacancy_description
    }

# %%
df_resumes = pd.read_csv('df_resumes.csv')

# %%
df_vacancy = pd.DataFrame([input_dict])

# %%
df = df_vacancy.merge(df_resumes, how='cross')

# %%
df_resumes[df_resumes['resume_id'] == 116651504]
# Out:
#      resume_id                resume_title  \
# 653  116651504  Data scientist/ML Engineer
#
#                                  resume_specialization resume_last_position  \
# 653  ['Аналитик', 'Дата-сайентист', 'Программист, р...       Data Scientist
#
#                     resume_last_experience_description  \
# 653  - Полный цикл процесса сбора, очистки и подгот...
#
#     resume_last_company_experience_period  \
# 653                            10 месяцев
#
#                                          resume_skills  \
# 653  [' Python', 'Machine Learning', 'Data Science'...
#
#                                       resume_education  \
# 653  ['ГУ «РНПЦ трансфузиологии и медицинских биоте...
#
#                             resume_courses  resume_salary  resume_age  \
# 653  ['TeachMeSkills, Python разработчик']            0.0        34.0
#
#     resume_total_experience  resume_experience_months resume_location  \
# 653         8 лет 9 месяцев                     105.0           Минск
#
#     resume_gender    resume_applicant_status  \
# 653       Мужчина  Рассматривает предложения
#
#      resume_last_company_experience_months
# 653                                     10

# %%
df[df['resume_id'] == 116651504]
# Out:
#                      vacancy_name vacancy_area  vacancy_experience  \
# 653  Аналитик данных/data analyst       Москва  От 1 года до 3 лет
#
#     vacancy_employment vacancy_schedule  \
# 653   Полная занятость      Полный день
#
#                                    vacancy_description  resume_id  \
# 653  Твои задачи:• Формирование баз данных для КЦ (...  116651504
#
#                    resume_title  \
# 653  Data scientist/ML Engineer
#
#                                  resume_specialization resume_last_position  \
# 653  ['Аналитик', 'Дата-сайентист', 'Программист, р...       Data Scientist
#
#      ...                                   resume_education  \
# 653  ...  ['ГУ «РНПЦ трансфузиологии и медицинских биоте...
#
#                             resume_courses resume_salary resume_age  \
# 653  ['TeachMeSkills, Python разработчик']           0.0       34.0
#
#     resume_total_experience  resume_experience_months  resume_location  \
# 653         8 лет 9 месяцев                     105.0            Минск
#
#     resume_gender    resume_applicant_status  \
# 653       Мужчина  Рассматривает предложения
#
#     resume_last_company_experience_months
# 653                                    10
#
# [1 rows x 23 columns]

# %% [markdown]
# # Cross features

# %%
df['location_matching'] = df.apply(lambda row: 1 if row['vacancy_area'] == row['resume_location'] else 0, axis=1)

# %%
def resume_skill_count_in_vacancy(row):
    count = 0
    skill_list = row['resume_skills'].replace('[', '').replace(']', '').replace("'", "").split(', ')
    for i in skill_list:
        if i in row['vacancy_description']:
            count += 1
    return count

df['resume_skill_count_in_vacancy'] = df.apply(resume_skill_count_in_vacancy, axis=1)

# %%
def last_position_in_vacancy(row):
    bow = []
    seps = [' ', '-', '_']
    for sep in seps:
        bow += row['resume_last_position'].split(sep=sep)
        bow = list(set(bow))
    
    c = 0
    for word in bow:
        if word in row['vacancy_description']:
            c +=1
    
    return c / len(bow)

df['last_position_in_vacancy'] = df.apply(last_position_in_vacancy, axis=1)

# %%
with open('tfidf_vectorizer.pkl', 'rb') as f:
    tfidf_vectorizer = pickle.load(f)

# %%
vacancy_description = df['vacancy_description'].unique().tolist()
vacancy_embedding = tfidf_vectorizer.transform(vacancy_description)

# %%
experience_embeddings = sp.load_npz('experience_embeddings.npz')

# %%
def calculate_cosine_similarity(vacancy_embedding, experience_embeddings):
    """Вычисление косинусного сходства"""
    similarities = []
    
    for i in range(experience_embeddings.shape[0]):
        exp_row = experience_embeddings[i]
        
        similarity = cosine_similarity(vacancy_embedding[0], exp_row)[0][0]
        similarities.append(similarity)
    
    return similarities

# %%
similarity_scores = calculate_cosine_similarity(vacancy_embedding, experience_embeddings)
    
df['similarity_score_tfidf'] = similarity_scores

# %%
features = [
    'vacancy_area',
    'vacancy_experience',
    'vacancy_employment', 
    'vacancy_schedule',
    'resume_salary',
    'resume_age', 
    'resume_experience_months',
    'resume_location',
    'resume_gender', 
    'resume_applicant_status', 
    'resume_last_company_experience_months', 
    'location_matching',
    'resume_skill_count_in_vacancy',
    'last_position_in_vacancy',
    'similarity_score_tfidf'
]
df[features]
# Out:
#       vacancy_area  vacancy_experience vacancy_employment vacancy_schedule  \
# 0           Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 1           Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 2           Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 3           Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 4           Москва  От 1 года до 3 лет   Полная занятость      Полный день
# ...            ...                 ...                ...              ...
# 20713       Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 20714       Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 20715       Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 20716       Москва  От 1 года до 3 лет   Полная занятость      Полный день
# 20717       Москва  От 1 года до 3 лет   Полная занятость      Полный день
#
#        resume_salary  resume_age  resume_experience_months resume_location  \
# 0                0.0        65.0                     228.0          Москва
# 1                0.0        43.0                     208.0          Москва
# 2           200000.0        52.0                     360.0          Москва
# 3           500000.0        56.0                     356.0      Красноярск
# 4                0.0        48.0                     301.0          Moscow
# ...              ...         ...                       ...             ...
# 20713       200000.0        50.0                     308.0          Moscow
# 20714        80000.0        40.0                     103.0          Москва
# 20715        40000.0        41.0                     134.0          Москва
# 20716            0.0        58.0                     220.0          Москва
# 20717        80000.0        62.0                     474.0          Москва
#
#       resume_gender    resume_applicant_status  \
# 0           Мужчина  Рассматривает предложения
# 1           Мужчина  Рассматривает предложения
# 2           Женщина                        NDT
# 3           Мужчина  Рассматривает предложения
# 4           Мужчина                        NDT
# ...             ...                        ...
# 20713       Мужчина                        NDT
# 20714       Мужчина                        NDT
# 20715       Мужчина                        NDT
# 20716       Женщина                        NDT
# 20717       Мужчина                        NDT
#
#        resume_last_company_experience_months  location_matching  \
# 0                                         76                  1
# 1                                          8                  1
# 2                                        136                  1
# 3                                        135                  0
# 4                                          0                  0
# ...                                      ...                ...
# 20713                                      0                  0
# 20714                                     47                  1
# 20715                                      2                  1
# 20716                                     91                  1
# 20717                                    177                  1
#
#        resume_skill_count_in_vacancy  last_position_in_vacancy  \
# 0                                  0                      0.00
# 1                                  0                      0.00
# 2                                  0                      0.00
# 3                                  0                      0.00
# 4                                  0                      0.00
# ...                              ...                       ...
# 20713                              0                      0.00
# 20714                              0                      0.00
# 20715                              0                      0.25
# 20716                              0                      0.00
# 20717                              0                      0.25
#
#        similarity_score_tfidf
# 0                    0.064805
# 1                    0.007989
# 2                    0.025913
# 3                    0.087667
# 4                    0.000000
# ...                       ...
# 20713                0.000000
# 20714                0.011738
# 20715                0.000000
# 20716                0.036427
# 20717                0.000000
#
# [20718 rows x 15 columns]

# %%
with open('feature_engineering_with_best_optuna_lr.pkl', 'rb') as f:
    model = pickle.load(f)

# %%
y_pred = model.predict(df[features])
y_pred_proba = model.predict_proba(df[features])

# %%
df['y_pred'] = y_pred
df['y_pred_proba'] = y_pred_proba[:, 1]

# %%
df.sort_values('y_pred_proba', ascending=False).head(10)
# Out:
#                        vacancy_name vacancy_area  vacancy_experience  \
# 8423   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 2589   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 20106  Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 5991   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 1315   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 1052   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 1072   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 1055   Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 716    Аналитик данных/data analyst       Москва  От 1 года до 3 лет
# 406    Аналитик данных/data analyst       Москва  От 1 года до 3 лет
#
#       vacancy_employment vacancy_schedule  \
# 8423    Полная занятость      Полный день
# 2589    Полная занятость      Полный день
# 20106   Полная занятость      Полный день
# 5991    Полная занятость      Полный день
# 1315    Полная занятость      Полный день
# 1052    Полная занятость      Полный день
# 1072    Полная занятость      Полный день
# 1055    Полная занятость      Полный день
# 716     Полная занятость      Полный день
# 406     Полная занятость      Полный день
#
#                                      vacancy_description  resume_id  \
# 8423   Твои задачи:• Формирование баз данных для КЦ (...      54799
# 2589   Твои задачи:• Формирование баз данных для КЦ (...       7092
# 20106  Твои задачи:• Формирование баз данных для КЦ (...     450698
# 5991   Твои задачи:• Формирование баз данных для КЦ (...     449402
# 1315   Твои задачи:• Формирование баз данных для КЦ (...    8664598
# 1052   Твои задачи:• Формирование баз данных для КЦ (...   20903580
# 1072   Твои задачи:• Формирование баз данных для КЦ (...   63289302
# 1055   Твои задачи:• Формирование баз данных для КЦ (...  135124273
# 716    Твои задачи:• Формирование баз данных для КЦ (...   86893416
# 406    Твои задачи:• Формирование баз данных для КЦ (...   54975055
#
#                                             resume_title  \
# 8423                Marketing, Sales, Project Management
# 2589                       Эксперт ГИС, менеджер проекта
# 20106                                           директор
# 5991                     Statistician / Modeling Manager
# 1315                             DevOps/tech lead DevOps
# 1052                      Аналитик данных (Data Analyst)
# 1072                                            Аналитик
# 1055                Аналитик данных (SQL, Excel, Python)
# 716                                      Аналитик данных
# 406    Программист, тестировщик, SEO-специалист, марк...
#
#                                    resume_specialization  \
# 8423   ['Менеджер по продажам, менеджер по работе с к...
# 2589                           ['Руководитель проектов']
# 20106                                         ['Другое']
# 5991                  ['Sales manager, account manager']
# 1315                                  ['DevOps-инженер']
# 1052   ['BI-аналитик, аналитик данных', 'Продуктовый ...
# 1072                                        ['Аналитик']
# 1055                                        ['Аналитик']
# 716         ['BI-аналитик, аналитик данных', 'Аналитик']
# 406    ['BI-аналитик, аналитик данных', 'SMM-менеджер...
#
#                                   resume_last_position  ...  \
# 8423              EE F&HC Business (Marketing) Analyst  ...
# 2589   Специалист географических информационных систем  ...
# 20106  генеральный директор – директор по производству  ...
# 5991                                           analyst  ...
# 1315                          Архитектор автоматизации  ...
# 1052                                   Аналитик данных  ...
# 1072                                          Аналитик  ...
# 1055                                          Аналитик  ...
# 716             Ведущий специалист (группа отчетности)  ...
# 406           Руководитель отдела маркетинга и рекламы  ...
#
#           resume_location resume_gender    resume_applicant_status  \
# 8423               Москва       Мужчина                        NDT
# 2589               Москва       Женщина                        NDT
# 20106  Московская область       Мужчина                        NDT
# 5991        Moscow Oblast       Женщина                        NDT
# 1315               Москва       Мужчина        Активно ищет работу
# 1052               Москва       Мужчина        Активно ищет работу
# 1072               Москва       Мужчина  Рассматривает предложения
# 1055               Москва       Женщина        Активно ищет работу
# 716           Новосибирск       Мужчина        Активно ищет работу
# 406                Москва       Мужчина        Активно ищет работу
#
#       resume_last_company_experience_months location_matching  \
# 8423                                      4                 1
# 2589                                    309                 1
# 20106                                   286                 0
# 5991                                      0                 0
# 1315                                      6                 1
# 1052                                      8                 1
# 1072                                     25                 1
# 1055                                     13                 1
# 716                                      19                 0
# 406                                      38                 1
#
#        resume_skill_count_in_vacancy  last_position_in_vacancy  \
# 8423                               0                  0.000000
# 2589                               0                  0.200000
# 20106                              0                  0.166667
# 5991                               0                  0.000000
# 1315                               0                  0.000000
# 1052                               2                  0.666667
# 1072                               1                  1.000000
# 1055                               0                  1.000000
# 716                                2                  0.000000
# 406                                2                  0.333333
#
#       similarity_score_tfidf  y_pred y_pred_proba
# 8423                0.000000       1     1.000000
# 2589                0.104827       1     1.000000
# 20106               0.021874       1     1.000000
# 5991                0.000000       1     1.000000
# 1315                0.013044       1     0.999952
# 1052                0.336429       1     0.999914
# 1072                0.295619       1     0.999813
# 1055                0.313912       1     0.999306
# 716                 0.256485       1     0.998675
# 406                 0.284891       1     0.998551
#
# [10 rows x 29 columns]

# %%
df[['vacancy_description', 'resume_last_experience_description']]
# Out:
#                                      vacancy_description  \
# 0      Твои задачи:• Формирование баз данных для КЦ (...
# 1      Твои задачи:• Формирование баз данных для КЦ (...
# 2      Твои задачи:• Формирование баз данных для КЦ (...
# 3      Твои задачи:• Формирование баз данных для КЦ (...
# 4      Твои задачи:• Формирование баз данных для КЦ (...
# ...                                                  ...
# 20713  Твои задачи:• Формирование баз данных для КЦ (...
# 20714  Твои задачи:• Формирование баз данных для КЦ (...
# 20715  Твои задачи:• Формирование баз данных для КЦ (...
# 20716  Твои задачи:• Формирование баз данных для КЦ (...
# 20717  Твои задачи:• Формирование баз данных для КЦ (...
#
#                       resume_last_experience_description
# 0      Участие в проектах:\r\nСибинтек (SAP MDG (Mast...
# 1      SAP S/4HANA (BTP, RAP, CDS, AMDP, ODATA V4, FI...
# 2      ABAP-разработчик (SAP Solution Manager)\n•\tУч...
# 3      Внедрение SAP ISU в МРСК-Сибири.\r\nМиграция д...
# 4      Projects:\r\nParticipated in 9 projects in Rus...
# ...                                                  ...
# 20713  HSBC :Hong Kong and Shanghai Banking Corporati...
# 20714  Обслуживание и ремонт систем кондиционирования...
# 20715              Обучение вновь прибывших сотрудников.
# 20716  Сопровождение VIP персон, организация встреч с...
# 20717  Руководство рабочими, прорабами, инженерами. О...
#
# [20718 rows x 2 columns]

# %%
df['resume_last_experience_description'][0]
# Out:
# 'Участие в проектах:\r\nСибинтек (SAP MDG (Master Data Governance),\r\nTELE2.\r\nРаботы выполняемые на проектах:\r\nРазработка функционала согласно спецификаций, модификация, расширение стандартной функциональности SAP (Enhancement, Customer-exit, Badi), написание отчетов (ALV), средства поиска. Формирование печатной документации (PDF, Excel), оптимизация программ, загрузка начальных данных (BAPI).'
